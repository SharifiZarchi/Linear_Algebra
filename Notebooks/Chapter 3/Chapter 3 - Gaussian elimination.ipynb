# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <div class="title">
#     <div dir="rtl" align="center">
#         به‌نام زیباترین
#     </div>
#     <div dir="rtl" align="center">
#         دانشگاه صنعتی شریف - دانشکده‌ی مهندسی کامپیوتر
#     </div>
#     <div dir="rtl" align="center" style="font-size:30pt;margin-bottom:10mm;font-weight:bold;">
#         جبرخطی
#     </div>
#     <div dir="rtl" align="center">
#         فصل سوم: روش حذف گاوس-جردن
#     </div>
#     <div dir="rtl" align="center">
#         علی شریفی
#         <hr>
#     </div>
# </div>

# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <div class="cell rtl-align" id="table_of_content">
#
# ## فهرست مطالب
#
# - [نمایش ماتریسی عملیات حذف](#sec_matrix_elimination)
# - [ماتریس افزوده](#sec_augmented_matrix)
# - [حل معادله $Ax=b$](#sec_ax_b)
# - [بدست آوردن معکوس ماتریس](#sec_inverse_matrix)
# - [تجزیه LU ماتریس مربعی](#sec_lu_decompose)
# - [تجزیه LDU ماتریس مربعی](#sec_ldu_decompose)
# - [فرم سطری یکانی](#sec_rref)
# - [منابع](#sec_resources)
#
# </div>

# %% [markdown]
# # حل معادله  Ax=b
# <div dir=rtl lang=fa >
# دستگاه خطی AX = b را در نظر بگیرید.
# برای تعداد جواب های دستگاه می توان سه حالت زیر را در نظر گرفت:
# <br>
# 1.دستگاه جوابی یکتا داشته باشد
# <br>
# 2.دستگاه بی شمار جواب داشته باشد
# <br>
# 3.دستگاه جوابی نداشته باشد
# <br>
# با کمک روش حذفی گاوس می توانیم پی ببریم که دستگاه خطی که داریم در کدام یک از سه دسته بالا قرار می گیرد و در صورت وجود جواب، آن را محاسبه کنیم.
# روش حذفی گاوس با کمک تبدیلات زیر انجام می شود :
# <br>
# 1.تعویض دو سطر یک ماتریس
# <br>
# 2.ضرب یک سطر در یک عدد ناصفر
# <br>
# 3.افزودن مضربی از یک سطر به سطر دیگر
# <br>
#
# </div>

# %% [markdown]
# # نمایش ماتریسی عملیات حذف

# %% [markdown]
# <div dir=rtl lang=fa >
# عملیات حذف گاوسی را می‌توان به شکل ماتریسی مانند مثال زیر نمایش داد. فرض کنید معادله‌ای به شکل زیر داریم:
# <br>
#
# $$
# -x + 4y - 2z = -15\\
# -4x + 6y + z = -5\\
# -6x - 6y -2z = -10
# $$
# <br>
# با قرار دادن هر معادله در یک سطر از یک  ماتریس می‌توانیم این دستگاه معادله را به صورت ماتریسی نمایش دهیم:
# <br>
# $$
# \left[
# \begin{matrix}
#     -1 & 4 & -2  \\
#     -4 & 6 & 1  \\
#     -6 & -6 & -2
#  \end{matrix}
# \, \middle\vert \,
# \begin{matrix}
# -15 \\ -5 \\ 10
# \end{matrix}
# \right]
# $$
# به این ماتریس، ماتریس افزوده می‌گویند.
# حالا می‌توانیم با قوانین گفته شده شروع به کاهش سطری ماتریس کنیم:
#
# $$
# L_1 ← -1 * L_1
# $$
#
# $$
# \left[
# \begin{matrix}
#     1 & -4 & 2  \\
#     -4 & 6 & 1  \\
#     -6 & -6 & -2
#  \end{matrix}
# \, \middle\vert \,
# \begin{matrix}
# 15 \\ -5 \\ 10
# \end{matrix}
# \right]
# $$
# حالا ستون اول دو سطر را صفر می‌کنیم:
# $$
# L_2 ← 4 L_1 +  L_2 \\
# L_3 ← 6L_1 + L_3
# $$
# $$
# \left[
# \begin{matrix}
#     1 & -4 & 2  \\
#     0 & -10 &  9 \\
#     0 & -30 & 10
#  \end{matrix}
# \, \middle\vert \,
# \begin{matrix}
# 15 \\ 55 \\ 80
# \end{matrix}
# \right]
# $$
# ستون دوم سطر دوم را یک می‌کنیم:
# $$
# L_2 ← \dfrac{-1}{10}  L_2 \\
# $$
# $$
# \left[
# \begin{matrix}
#     1 & -4 & 2  \\
#     0 & 1 &  -0.9 \\
#     0 & -30 & 10
#  \end{matrix}
# \, \middle\vert \,
# \begin{matrix}
# 15 \\ -5.5 \\ 80
# \end{matrix}
# \right]
# $$
# <br><br>
# $$
# L_3 ← 30 L_2 + L_3
# $$
# $$
# \left[
# \begin{matrix}
#     1 & -4 & 2  \\
#     0 & 1 &  -0.9 \\
#     0 & 0 & -27
#  \end{matrix}
# \, \middle\vert \,
# \begin{matrix}
# 15 \\ -5.5 \\ -85
# \end{matrix}
# \right]
# $$
# <br><br>
# $$
# L_3 ← \dfrac{-1}{17} L_3
# $$
# $$
# \left[
# \begin{matrix}
#     1 & -4 & 2  \\
#     0 & 1 &  -0.9 \\
#     0 & 0 & 1
#  \end{matrix}
# \, \middle\vert \,
# \begin{matrix}
# 15 \\ -5.5 \\ 5
# \end{matrix}
# \right]
# $$
# پس دستگاه معادله قبلی برابر این دستگاه معدله جدید است:
# $$
# x - 4y + 2z = 15\\
# y - 0.9z = -5.5\\
# z = 5
# $$
# که حل آن به سادگی نشان می‌دهد:
# $$
# x = 1 \\
# y = -1
# $$
# </div>

# %% [markdown]
# # بدست آوردن معکوس ماتریس
# $$
#  A =  \left[ \begin{array}{cc}
# \frac{17}{20} & \frac{1}{10} \\ \frac{1}{10} & \frac{19}{20} \\ \end{array} \right],\quad V^{(0)} =  \left[ \begin{array}{c}
# 0 \\ 1 \\ \end{array} \right]
# $$

# %% [markdown]
# # تجزیه ماتریس مربعی LU

# %% [markdown]
# <div dir=rtl lang=fa >
#
# در قسمت قبل  پروسه ی حل دستگاه های نامنفرد
# $Ax=b$
# را با استفاده از روش حذفی گاوس بررسی  کردیم،‌ در این مسیر نیاز داشتیم تا ماتریس افزوده  را تشکیل دهیم و آنرا به فرم بالا مثلثی در بیاریم و با استفاده از جایگذاری پسرو بردار جواب دستگاه را پیدا کنیم
#
#
#
# حال در بسیاری از کاربردهایی که دستگاه های خطی ظاهر میشوند ما نیاز داریم تا دستگاه
# $Ax=b$
#  را به ازای  تعداد زیادی بردار متفاوت
# $b$
# حل کنیم
# .
#
# برای مثال پل معلقی را در نظر بگیرید که باید شرایط آن در موقعیت های متفاوت  برای مثال وزن های متفاوت بررسی و محاسبه گردد، در این شرایط ماتریس ضرایب یا همان
# $A$
# ثابت و بردار
# $b$
# متغییر است
# .
#
# برای حل این دستگاه ها با استفاده از روش حذفی گاوس ما نیاز داریم تا عملیات سطری برای تبدیل ماتریس افزوده به ماتریس بالا مثلثی و جایگذاری پسرو را برای هر یک از این دستگاه ها انجام دهیم
# اینجاست که ما میخواهیم از عملیات های سطری تکرار شونده در روش حذفی گاوس برای حل دستگاه هایی با بردار
# $b$
#  متفاوت و ماتریس ضرایب یکسان جلوگیری کنیم
#
# همچنین باید توجه کنیم که الگوریتم حذفی گاوس در تمامی شرایط پایدار نیست و باید
# محورگیری نیز برای هر یک از دستگاه ها اتخاذ شود
# .
# </br>
# </br>
#
#
# ***ایده ی اصلی برای حل این مشکل***
#
# </br>
# اگر ماتریس
# $A$
# را بتوانیم به صورت حاصل ضرب دو ماتریس پایین مثلثی و بالا مثلثی بنویسیم
# به دلیل فرمت ساده ی دو ماتریس پایین مثلثی و بالا مثلثی میتوانیم با یک بار استفاده از جایگذاری پیشرو و یک بار جایگذاری پسرو دستگاه معادلات را حل کنیم، همچنین که در هر دستگاهی که ماتریس ضرایب آن
#  $A$
#  بود میتوانیم از این تجزیه ای که ارائه کردیم استفاده کنیم و فقط با استفاده از جایگذاری ها جواب دستگاه را بدست آوریم
# .
#
# برای مثال
#
#
# $$
#  A =  \left[ \begin{array}{cc}
# 2 & 4 \\ 3 & 5 \\ \end{array} \right]
# $$
#
# </br>
#
# $$
# A = \left[ \begin{array}{cc}
# l_{11} & 0 \\ l_{21} & l_{22} \\ \end{array} \right]\left[ \begin{array}{cc}
# u_{11} & u_{12} \\ 0 & u_{22} \\ \end{array} \right]
# $$
#
# </br>
# </br>
#
# $$
# A = \left[ \begin{array}{cc}
# 1 & 0 \\ 1.5 & 1 \\ \end{array} \right]\left[ \begin{array}{cc}
# 2 & 4 \\ 0 & -1 \\ \end{array} \right]
# $$
#
#
# و برای حل دستگاه
# $Ax = b$
# که
#
# $$
# b =  \left[ \begin{array}{c}
# 6 \\ 8 \\ \end{array} \right]
# $$
#
# کافیست با جایگذاری پیشرو دستگاه
# $Ly=b$
# را حل کرده و سپس با جایگذاری پسرو دستگاه
# $Ux=y$
# را حل کنیم
#
# </br>
#
# $$
# \left[ \begin{array}{cc}
# 1 & 0 \\ 1.5 & 1 \\ \end{array} \right]\left[ \begin{array}{c}
# y_1 \\ y_2 \\ \end{array} \right] = \left[ \begin{array}{c}
# 6 \\ 8 \\ \end{array} \right]
# $$
#
# <br/>
# $$
# y = \left[ \begin{array}{c}
# 6 \\ -1 \\ \end{array} \right]
# $$
#
# <br/>
#
# $$
# \left[ \begin{array}{cc}
# 2 & 4 \\ 0 & -1 \\ \end{array} \right]\left[ \begin{array}{c}
# x_1 \\ x_2 \\ \end{array} \right] = \left[ \begin{array}{c}
# 6 \\ -1 \\ \end{array} \right]
# $$
#
# <br/>
# $$
# x = \left[ \begin{array}{c}
# 1 \\ 1 \\ \end{array} \right]
# $$
#
#
# <br/>
# <br/>
# توجه کنید که این تجزیه ممکن است یکتا نباشد،‌ همچنین اگر قطر اصلی ماتریس پایین مثلثی 1 باشد به آن تجزیه دولیتل و اگر قطر اصلی ماتریس بالا مثلثی 1 باشد به آن
# تجزیه کروت میگویند
# .
#
# <br/>
# <br/>
#
#  *برای بدست آوردن درایه های این ماتریس در حالت کلی نیز کافیست همانند الگوریتم زیر عمل کنیم*
#
# </div>

# %%
# Python3 Program to decompose
# a matrix into lower and
# upper triangular matrix
MAX = 100


def luDecomposition(mat, n):

	lower = [[0 for x in range(n)]
			for y in range(n)]
	upper = [[0 for x in range(n)]
			for y in range(n)]

	# Decomposing matrix into Upper
	# and Lower triangular matrix
	for i in range(n):

		# Upper Triangular
		for k in range(i, n):

			# Summation of L(i, j) * U(j, k)
			sum = 0
			for j in range(i):
				sum += (lower[i][j] * upper[j][k])

			# Evaluating U(i, k)
			upper[i][k] = mat[i][k] - sum

		# Lower Triangular
		for k in range(i, n):
			if (i == k):
				lower[i][i] = 1 # Diagonal as 1
			else:

				# Summation of L(k, j) * U(j, i)
				sum = 0
				for j in range(i):
					sum += (lower[k][j] * upper[j][i])

				# Evaluating L(k, i)
				lower[k][i] = int((mat[k][i] - sum) /
								upper[i][i])

	# setw is for displaying nicely
	print("Lower Triangular\t\tUpper Triangular")

	# Displaying the result :
	for i in range(n):

		# Lower
		for j in range(n):
			print(lower[i][j], end="\t")
		print("", end="\t")

		# Upper
		for j in range(n):
			print(upper[i][j], end="\t")
		print("")

# %%
# @title utils

print('hello')

# %%
# Driver code
mat = [
	[2, -1, -2],
	[-4, 6, 3],
	[-4, -2, 8]
	]

luDecomposition(mat, 3)
# Out:
# Lower Triangular		Upper Triangular
# 1	0	0		2	-1	-2
# -2	1	0		0	4	-1
# -2	-1	1		0	0	3

# %% [markdown]
# <div dir=rtl >
#
# ***قضایای مربوط به تجزیه LU***
#
# 1. اگر همه زیرماتریس های پیشرو ماتریس
# $A$
# نامنفرد باشند، آنگاه تجزیه یکتای
# $A$
# به صورت
# $A=LU$
# وجود خواهد داشت، به طوری که اعضای قطری
# $L$
# یا
# $U$
# واحد باشد
# .
#
#
#
# 2. فرض کنید
# $A$
# ماتریسی وارون پذیر است
# .
# اگر در تجزیه
# $LU$
# ماتریس
# $A$
# اعضای روی قطر
# $L$
# یا
# $U$
# همگی یک باشند آنگاه این تجزیه یکتا است.
#
#
#
# ***نکات مربوط به تجزیه LU***
# 1. اگر ماتریس به صورت
# $A = LU$
# تجزیه شود، آنگاه محاسبه دترمینان آن ساده میشود
# :
# $$
# A = LU ⟹ det(A) = det(LU) = det(L).det(U) = l_{11} ... l_{nn}u_{11}...u_{nn}
# $$
#
# 2. پیچیدگی محاسباتی تجزیه دولیتل برای ماتریس های
# $n × n$
# ، از
# $O(n^3)$
# است.
# </div>

# %% [markdown]
# # تجزیه LDU ماتریس مربعی

# %% [markdown]
# # فرم سطری پکانی

# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <div class="cell rtl-align" id="sec_resources">
#
# ## منابع
#
# - **منبع اول**
# - **منبع دوم**
# - **منبع سوم**
# - **منبع چهارم**
#
# [بازگشت به فهرست مطالب](#table_of_content)
#
# <div>
